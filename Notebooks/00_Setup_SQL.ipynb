# %%
# %sql
CREATE CATALOG IF NOT EXISTS fhir_assignment;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS fhir_assignment.raw;

CREATE SCHEMA IF NOT EXISTS fhir_assignment.bronze;

CREATE SCHEMA IF NOT EXISTS fhir_assignment.silver;

CREATE SCHEMA IF NOT EXISTS fhir_assignment.gold;

# %%
# %sql
SHOW SCHEMAS IN fhir_assignment;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS fhir_assignment.raw.fhir_files;

# %%
# %sql

LIST '/Volumes/fhir_assignment/raw/fhir_files/Patient/2026-08-14_2026-08-16';
